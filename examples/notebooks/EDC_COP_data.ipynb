# %% [markdown]
# ### nc2zarr demo notebook

# %% [markdown]
#  Import some necessary libraries.

# %%
import s3fs
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import xcube.core.store
# requires conda install -c conda-forge nc-time-axis
import nc_time_axis

# %% [markdown]
# Create an xcube S3 store as an alternative way to open datasets.

# %%
xcube_store = xcube.core.store.new_data_store("s3", anon=True, bucket_name="cop-services")
LoXCs =list(xcube_store.get_data_ids(include_titles=True))
LoXCs
# Out:
# [('OCEANCOLOUR_BAL_CHL_L3_NRT_OBSERVATIONS_009_049.zarr', None),
#  ('OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045-no-rechunk.zarr', None),
#  ('OCEANCOLOUR_BS_CHL_L4_NRT_OBSERVATIONS_009_045.zarr', None),
#  ('OCEANCOLOUR_MED_CHL_L4_NRT_OBSERVATIONS_009_041-no-rechunk.zarr', None),
#  ('OCEANCOLOUR_MED_CHL_L4_NRT_OBSERVATIONS_009_041.zarr', None)]

# %% [markdown]
# ### Black Sea

# %%
BlackSea = xcube_store.open_data(LoXCs[2][0])

# %%
BlackSea.CHL.isel(time=0).plot(vmax=1.)

# %%
BlackSea.CHL.sel(lat=44.,lon=34.,method='nearest').plot()

# %% [markdown]
# ### Med Sea

# %%
MedSea = xcube_store.open_data(LoXCs[4][0])

# %%
MedSea.CHL.isel(time=0).plot(vmax=1.)

# %%
MedSea.CHL.sel(lat=40.,lon=5.,method='nearest').plot()

# %% [markdown]
# ### Baltic

# %%
Baltic = xcube_store.open_data(LoXCs[0][0])

# %%
Baltic.CHL.isel(time=0).plot(vmax=1.)

# %%
Baltic.CHL.sel(lat=54.2,lon=11.3,method='nearest').plot()
